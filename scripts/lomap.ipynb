# %%
import BioSimSpace as bss
# import nglview as nv
import glob
# Out:
# /home/jguven/Software/miniconda3/envs/sire/lib/python3.9/site-packages/numpy/core/getlimits.py:500: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/jguven/Software/miniconda3/envs/sire/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/jguven/Software/miniconda3/envs/sire/lib/python3.9/site-packages/numpy/core/getlimits.py:500: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/jguven/Software/miniconda3/envs/sire/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %%
path_to_ligands = "../vim_2/inputs/ligands/"
working_directory = "/home/jguven/projects/metalloenzymes/vim_2/inputs/ligands/"

# %%
ligand_files = sorted(glob.glob(f"{path_to_ligands}/docked_*.sdf"))
print(ligand_files)
ligands = []
ligand_names = []

for filepath in ligand_files:
    ligands.append(bss.IO.readMolecules(filepath)[0])
    ligand_names.append(filepath.split("/")[-1].replace(".sdf",""))

transformations, lomap_scores = bss.Align.generateNetwork(ligands, plot_network=True, names=ligand_names, work_dir=working_directory)
# Out:
# ['../vim_2/inputs/ligands/docked_1.sdf', '../vim_2/inputs/ligands/docked_10.sdf', '../vim_2/inputs/ligands/docked_11.sdf', '../vim_2/inputs/ligands/docked_12.sdf', '../vim_2/inputs/ligands/docked_13.sdf', '../vim_2/inputs/ligands/docked_14.sdf', '../vim_2/inputs/ligands/docked_15.sdf', '../vim_2/inputs/ligands/docked_16.sdf', '../vim_2/inputs/ligands/docked_2.sdf', '../vim_2/inputs/ligands/docked_3.sdf', '../vim_2/inputs/ligands/docked_4.sdf', '../vim_2/inputs/ligands/docked_5.sdf', '../vim_2/inputs/ligands/docked_6.sdf', '../vim_2/inputs/ligands/docked_7.sdf', '../vim_2/inputs/ligands/docked_9.sdf']
#
# ==============================================================
# Sending anonymous Sire usage statistics to http://siremol.org.
# For more information, see http://siremol.org/analytics
# To disable, set the environment variable 'SIRE_DONT_PHONEHOME' to 1
# To see the information sent, set the environment variable
# SIRE_VERBOSE_PHONEHOME equal to 1. To silence this message, set
# the environment variable SIRE_SILENT_PHONEHOME to 1.
# ==============================================================

# %%
for i in range(len(ligands)):
    print(i+1, ligand_files[i])
# Out:
# 1 ../inputs/ligands/docked_1.sdf
# 2 ../inputs/ligands/docked_10.sdf
# 3 ../inputs/ligands/docked_11.sdf
# 4 ../inputs/ligands/docked_12.sdf
# 5 ../inputs/ligands/docked_13.sdf
# 6 ../inputs/ligands/docked_14.sdf
# 7 ../inputs/ligands/docked_15.sdf
# 8 ../inputs/ligands/docked_16.sdf
# 9 ../inputs/ligands/docked_2.sdf
# 10 ../inputs/ligands/docked_3.sdf
# 11 ../inputs/ligands/docked_4.sdf
# 12 ../inputs/ligands/docked_5.sdf
# 13 ../inputs/ligands/docked_6.sdf
# 14 ../inputs/ligands/docked_7.sdf
# 15 ../inputs/ligands/docked_9.sdf
# 16 ../inputs/ligands/ligand_3.sdf
# 17 ../inputs/ligands/ligand_8.sdf

# %%
pert_network_dict = {}
transformations_named = [(ligand_names[transf[0]], ligand_names[transf[1]]) for transf in transformations]
for transf, score in zip(transformations_named, lomap_scores):
    print(transf, score)
    pert_network_dict[transf] = score
# Out:
# ('docked_1', 'docked_4') 0.90484
# ('docked_1', 'docked_5') 0.90484
# ('docked_10', 'docked_16') 0.2466
# ('docked_10', 'docked_6') 0.95123
# ('docked_10', 'docked_9') 0.95123
# ('docked_11', 'docked_3') 0.70469
# ('docked_11', 'docked_4') 0.86071
# ('docked_11', 'docked_5') 0.86071
# ('docked_12', 'docked_14') 0.74082
# ('docked_12', 'docked_16') 0.74082
# ('docked_13', 'docked_16') 0.2466
# ('docked_13', 'docked_6') 0.95123
# ('docked_13', 'docked_9') 0.90484
# ('docked_14', 'docked_15') 0.90484
# ('docked_15', 'docked_16') 0.74082
# ('docked_2', 'docked_4') 0.86071
# ('docked_2', 'docked_9') 0.7788
# ('docked_4', 'docked_9') 0.90484
# ('docked_6', 'docked_7') 0.86071
# ('docked_7', 'docked_9') 0.86071
